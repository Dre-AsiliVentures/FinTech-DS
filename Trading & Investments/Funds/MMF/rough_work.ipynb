# %%
start_date='01/05/2022'
end_date='01/10/2023'

# %%
fart=['Kushuta','Kunyamba','Kuchachisha','Kuachilia','Kukojoa']

# %%
del fart[-1]

# %%
import pandas as pd
testCSV=pd.read_csv('Paybill Charges.csv')
#testCSV

# %%
testCSV
# Out:
#       MIN     MAX MGAO TARIFF Unnamed: 3 Unnamed: 4 BUSINESS BOUQUET TARIFF  \
# 0       0       0    CUSTOMER   BUSINESS      TOTAL                CUSTOMER
# 1       1      49       Free*      Free*      Free*                   Free*
# 2      50     100       Free*      Free*      Free*                   Free*
# 3     101     499          23          0         23                      23
# 4     500     999          23          0         23                      23
# 5    1000    1499          23         12         35                      34
# 6    1500    2499          23         12         35                      34
# 7    2500    3499          34         22         56                      56
# 8    3500    4999          34         22         56                      56
# 9    5000    7499          34         51         85                      85
# 10   7500    9999          34         51         85                      85
# ...

# %%
#testCSV.set_index('MIN',inplace=True)

# %%
testCSV.at[3,'MIN']
# Out:
# 101

# %%
def transactionCost(amount):
    amount=int(amount)
    'This Function only assumes that the person is  customer'
    # Support for Business coming soon
    print("You will be prompted to enter Tariff type")
    #tariffType='Business'
    tariffType=input("Enter the tarrif type: MGAO / BUSINESS / CUSTOMER")
    for row in range(0,len(testCSV)):
        min=int(testCSV.at[row,'MIN'])
        max=int(testCSV.at[row,'MAX'])
        if amount>=min and amount<=min:
            if tariffType=='MGAO' or tariffType=='mgao' or tariffType=='Mgao':
                print("The row is:{}".format(row))
                print(testCSV.iat[row,2])
            elif tariffType=='Business' or tariffType=='BUSINESS' or tariffType=='business':
                print("The row is:{}".format(row))
                print(testCSV.iat[row,5])
            elif tariffType=='Customer' or tariffType=='CUSTOMER' or tariffType=='customer':
                print("The row is:{}".format(row))
                print(testCSV.iat[row,8])
            else:
                pass

# %%
calendar_months=['Jan','Feb','Mar','Apr','May','Jun','July','Aug','Sep','Oct','Nov','Dec']

# %%
calendar_months[11] in firstDate_range
# Out:
# False

# %%
calendar_months[0] in firstDate_range
# Out:
# False

# %%
(calendar_months[11] in firstDate_range) and (calendar_months[0] in firstDate_range)
# Out:
# False

# %%
start_date= "01/08/2022"
end_date= '01/11/2025'

# %%
firstDate_range = pd.date_range(start=start_date, end=end_date,freq='MS')
fourthDate_range = pd.date_range(start=start_date, end=end_date,freq='MS').shift(3,freq='D')

# %%
13//12
# Out:
# 1

# %%
interest=self.interest(self.runningBal)[1]
                    self.runningBal+=interest
